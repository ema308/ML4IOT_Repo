# %% [markdown]
# # MQTT Subscriber

# %% [markdown]
# ## Import the required module

# %%
import paho.mqtt.client as mqtt
import json

# %% [markdown]
# ### Connection to Redis

# %%
import redis

REDIS_HOST = 'redis-11392.c300.eu-central-1-1.ec2.redns.redis-cloud.com'
REDIS_PORT = 11392
REDIS_USERNAME = 'default'
REDIS_PASSWORD = 'nVukRxv3hvJTuYLkK6n4XdWF8etIzoOO'


redis_client = redis.Redis(host=REDIS_HOST, port=REDIS_PORT, username=REDIS_USERNAME, password=REDIS_PASSWORD)
is_connected = redis_client.ping()
print('Redis Connected:', is_connected)
# Out:
# Redis Connected: True

# %% [markdown]
# ## Create a new MQTT client

# %%
client = mqtt.Client()

# %% [markdown]
# ## Define the callback for when the client receives a response from the MQTT broker

# %%
def on_connect(client, userdata, flags, rc):
    print(f'Connected with result code {str(rc)}')
    # Subscribe to a topic when the client connects
    client.subscribe('s333550')

# %% [markdown]
# ## Define the callback for when a message is published on a subscribed topic

# %%
def on_message(client, userdata, msg):
    # Decode the message
    message = msg.payload.decode()

    # Decode JSON string to dict
    my_dict = json.loads(message)

    #parameters of the message
    mac_address = my_dict['mac_address']
    timestamp = int(my_dict['timestamp'])*1000  # Ensure timestamp is an integer and is in milliseconds
    temperature = float(my_dict['temperature'])  # Ensure temperature is numeric
    humidity = float(my_dict['humidity'])  # Ensure humidity is numeric

    """create the time-series"""
    # Set the retention of "temperature" and "humidity" to 365 days
    thirty_day_in_ms = 365 * 24 * 60 * 60 * 1000
    try:
        redis_client.ts().create(f'{mac_address}:temperature', retention_msecs=thirty_day_in_ms, uncompressed=False, chunk_size=128,)
    except redis.ResponseError:
        pass

    try:
        redis_client.ts().create(f'{mac_address}:humidity', retention_msecs=thirty_day_in_ms, uncompressed=False, chunk_size=128,)
    except redis.ResponseError:
        pass


    #Add temperature and humidity data to Redis time series
    redis_client.ts().add(f'{mac_address}:temperature', timestamp, temperature)
    redis_client.ts().add(f'{mac_address}:humidity', timestamp, humidity)

    # Print the message and its topic
    print(f"Received message '{message}' on topic {msg.topic}")

# %% [markdown]
# ## Set the callbacks to the client object

# %%
client.on_connect = on_connect
client.on_message = on_message

# %% [markdown]
# ## Connect to the MQTT broker and wait for messages

# %%
client.connect('mqtt.eclipseprojects.io', 1883)

# Start the client loop to process network events and call the callbacks
client.loop_forever()
# Out:
# Connected with result code 0
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467300.3312886, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467302.586188, "temperature": 33, "humidity": 5}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467304.8405037, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467307.0948474, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467309.3493822, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467311.6034698, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467313.8578596, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467316.11461, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467318.3689868, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467320.6230485, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467322.8774493, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467325.1317484, "temperature": 33, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467327.3909123, "temperature": 33, "humidity": 9}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467329.6461902, "temperature": 33, "humidity": 13}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467331.9014027, "temperature": 33, "humidity": 14}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467334.1621127, "temperature": 33, "humidity": 14}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467336.4198387, "temperature": 33, "humidity": 15}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467338.674245, "temperature": 33, "humidity": 16}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467340.9285831, "temperature": 34, "humidity": 16}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467343.1829627, "temperature": 33, "humidity": 16}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467345.4376068, "temperature": 33, "humidity": 16}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467347.6922581, "temperature": 33, "humidity": 13}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467349.9468558, "temperature": 34, "humidity": 10}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467352.2017057, "temperature": 34, "humidity": 10}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467354.4583519, "temperature": 34, "humidity": 9}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467356.7129612, "temperature": 34, "humidity": 9}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467358.9675786, "temperature": 34, "humidity": 9}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467361.2223341, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467363.476626, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467365.731255, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467367.9861681, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467370.240804, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467372.500614, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467374.7550366, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467377.009418, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467379.2639978, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467381.5184016, "temperature": 34, "humidity": 8}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467383.7727711, "temperature": 34, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467386.0272894, "temperature": 34, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467388.281679, "temperature": 34, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467390.536114, "temperature": 34, "humidity": 6}' on topic s333550
# Received message '{"mac_address": "0xe45f01e89bcc", "timestamp": 1735467392.7904856, "temperature": 34, "humidity": 6}' on topic s333550
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 client.connect('mqtt.eclipseprojects.io', 1883)
#       3 # Start the client loop to process network events and call the callbacks
# ----> 4 client.loop_forever()
#
# File ~/venv/lib/python3.11/site-packages/paho/mqtt/client.py:1756, in Client.loop_forever(self, timeout, max_packets, retry_first_connection)
#    1754 rc = MQTT_ERR_SUCCESS
#    1755 while rc == MQTT_ERR_SUCCESS:
# -> 1756     rc = self._loop(timeout)
#    1757     # We don't need to worry about locking here, because we've
#    1758     # either called loop_forever() when in single threaded mode, or
#    1759     # in multi threaded mode when loop_stop() has been called and
#    1760     # so no other threads can access _out_packet or _messages.
#    1761     if (self._thread_terminate is True
#    1762         and len(self._out_packet) == 0
#    1763             and len(self._out_messages) == 0):
#
# File ~/venv/lib/python3.11/site-packages/paho/mqtt/client.py:1150, in Client._loop(self, timeout)
#    1147     rlist = [self._sock, self._sockpairR]
#    1149 try:
# -> 1150     socklist = select.select(rlist, wlist, [], timeout)
#    1151 except TypeError:
#    1152     # Socket isn't correct type, in likelihood connection is lost
#    1153     return MQTT_ERR_CONN_LOST
#
# KeyboardInterrupt:

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8a9d9526-dc21-42d6-ba37-8f708634743d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
